# %%
# !pip install bamboolib

# Jupyter Notebook extensions
# !python -m bamboolib install_nbextensions

# JupyterLab extensions
# !python -m bamboolib install_labextensions
# Out:
# Requirement already satisfied: bamboolib in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (1.26.0)
# Requirement already satisfied: toml>=0.10.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (0.10.2)
# Requirement already satisfied: packaging>=19.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (20.9)
# Requirement already satisfied: attrs>=20.3.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (20.3.0)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.6.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (7.6.3)
# Requirement already satisfied: jupyterlab<4.0.0,>=2.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (3.0.14)
# Requirement already satisfied: notebook<7.0.0,>=5.3.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (6.3.0)
# Requirement already satisfied: scikit-learn<1.0.0,>=0.20.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (0.24.1)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (1.2.4)
# Requirement already satisfied: plotly<5.0.0,>=4.9.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (4.14.3)
# Requirement already satisfied: xlrd>=1.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (2.0.1)
# Requirement already satisfied: psutil<6,>=5.4.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (5.8.0)
# Requirement already satisfied: jedi<1.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (0.17.2)
# Requirement already satisfied: ipyslickgrid==0.0.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (0.0.3)
# Requirement already satisfied: seaborn<0.11,>=0.10 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (0.10.1)
# Requirement already satisfied: analytics-python==1.2.9 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (1.2.9)
# Requirement already satisfied: ppscore<2.0.0,>=1.2.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (1.2.0)
# Requirement already satisfied: cryptography<3.0.0,>=2.6.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bamboolib) (2.9.2)
# Requirement already satisfied: python-dateutil>2.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib) (2.8.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib) (2.25.1)
# Requirement already satisfied: six>=1.5 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib) (1.15.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from cryptography<3.0.0,>=2.6.1->bamboolib) (1.14.5)
# Requirement already satisfied: pycparser in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography<3.0.0,>=2.6.1->bamboolib) (2.20)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (7.22.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib) (5.1.3)
# Requirement already satisfied: appnope in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib) (0.1.2)
# Requirement already satisfied: tornado>=4.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib) (6.1)
# Requirement already satisfied: jupyter-client in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib) (6.1.12)
# Requirement already satisfied: pygments in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (2.8.1)
# Requirement already satisfied: pickleshare in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (52.0.0.post20210125)
# Requirement already satisfied: backcall in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (0.2.0)
# Requirement already satisfied: decorator in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (5.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (4.8.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jedi<1.0.0->bamboolib) (0.7.0)
# Requirement already satisfied: jupyter-packaging~=0.7 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (0.7.12)
# Requirement already satisfied: nbclassic~=0.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (0.2.6)
# Requirement already satisfied: jupyter-core in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (4.7.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (2.4.0)
# Requirement already satisfied: jupyter-server~=1.4 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (1.4.1)
# Requirement already satisfied: jinja2>=2.10 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4.0.0,>=2.0->bamboolib) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.10->jupyterlab<4.0.0,>=2.0->bamboolib) (1.1.1)
# Requirement already satisfied: terminado>=0.8.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.9.4)
# Requirement already satisfied: pyzmq>=17 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (20.0.0)
# Requirement already satisfied: prometheus-client in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.10.1)
# Requirement already satisfied: nbconvert in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (6.0.7)
# Requirement already satisfied: Send2Trash in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (1.5.0)
# Requirement already satisfied: ipython-genutils in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.2.0)
# Requirement already satisfied: anyio>=2.0.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (2.10)
# Requirement already satisfied: babel in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab<4.0.0,>=2.0->bamboolib) (2.9.0)
# Requirement already satisfied: json5 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab<4.0.0,>=2.0->bamboolib) (0.9.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab<4.0.0,>=2.0->bamboolib) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab<4.0.0,>=2.0->bamboolib) (0.17.3)
# Requirement already satisfied: argon2-cffi in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from notebook<7.0.0,>=5.3.0->bamboolib) (20.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from packaging>=19.2->bamboolib) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.1.0->bamboolib) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.1.0->bamboolib) (1.20.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (0.7.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from plotly<5.0.0,>=4.9.0->bamboolib) (1.3.3)
# Requirement already satisfied: wcwidth in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib) (0.2.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<1.0.0,>=0.20.2->bamboolib) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<1.0.0,>=0.20.2->bamboolib) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<1.0.0,>=0.20.2->bamboolib) (1.0.1)
# Requirement already satisfied: matplotlib>=2.1.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from seaborn<0.11,>=0.10->bamboolib) (3.3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib) (0.10.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.3)
# Requirement already satisfied: bleach in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.1.2)
# Requirement already satisfied: testpath in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.4.4)
# Requirement already satisfied: defusedxml in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.7.1)
# Requirement already satisfied: nest-asyncio in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (1.5.1)
# Requirement already satisfied: async-generator in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (1.10)
# Requirement already satisfied: webencodings in /Users/adeep/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab<4.0.0,>=2.0->bamboolib) (0.5.1)
# Trying to install bamboolib nbextension...
# Finished installing the bamboolib Jupyter Notebook nbextension
# Please reload your Jupyter notebook browser window
# Trying to install bamboolib labextensions...
# Installing ipyslickgrid: ... done
# Installing plotlywidget@4.14.3: ... done
# Installing jupyterlab-plotly@4.14.3: ... done
# Installing bamboolib@1.26.0: ... done
# Starting JupyterLab build. This may take a while ...
# Building jupyterlab assets (production, minimized)
# Successfully built JupyterLab
#
# Please reload your Jupyter Lab browser window

# %%
import pandas as pd
import bamboolib as bam
df = pd.read_csv("user_movie_ratings_10k.csv")

# %%
df
# Out:
#       index            Timestamp  user_id                    movie_id  Rating
# 0         1  2022-01-04 14:33:14   824851           carlitos+way+1993       4
# 1         2  2022-01-04 14:51:49   972501      the+mummy+returns+2001       2
# 2         3  2022-01-04 15:42:36   530452           forrest+gump+1994       4
# 3         4  2022-01-04 15:50:47   571839  to+kill+a+mockingbird+1962       5
# 4         5  2022-01-04 17:02:31   237539       the+muppet+movie+1979       3
# ...     ...                  ...      ...                         ...     ...
# 9994   9995  2021-12-31 16:03:06    83565                 jaws+2+1978       1
# 9995   9996  2022-01-21 19:55:43   443188                aladdin+1992       4
# 9996   9997  2021-12-31 16:27:48   180156                  smoke+1995       5
# 9997   9998  2021-12-31 16:33:12   828223                amadeus+1984       4
# 9998   9999  2021-12-31 16:39:58   106739          jerry+maguire+1996       5
#
# [9999 rows x 5 columns]
